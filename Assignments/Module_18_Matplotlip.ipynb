# %% [markdown]
# # Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib.

# %% [raw]
# Matplotlib is a widely-used plotting library for the Python programming language. It provides a comprehensive suite of tools for creating static, animated, and interactive visualizations in Python. Matplotlib is particularly well-known for its capability to produce publication-quality plots and graphs with a high degree of customization.
# Why is Matplotlib Used?
#
#     Wide Range of Plot Types:
#         Matplotlib supports a variety of plot types, including line plots, scatter plots, bar charts, histograms, pie charts, 3D plots, and more.
#
#     Highly Customizable:
#         It offers extensive customization options for almost every aspect of a plot, including colors, labels, line styles, markers, and fonts.
#
#     Publication-Quality Figures:
#         It is capable of producing high-quality figures suitable for publication, making it a favorite tool in academia and research.
#
#     Integration with Other Libraries:
#         Matplotlib integrates well with other scientific and data analysis libraries such as NumPy, pandas, and SciPy, enabling seamless data visualization workflows.
#
#     Interactive Plots:
#         While primarily known for static plots, Matplotlib can also create interactive plots when combined with other libraries like Jupyter Notebook and IPython.
#
#     Community and Documentation:
#         It has a large and active community, extensive documentation, and numerous examples available online, which makes it easier for new users to learn and for experienced users to find solutions and best practices.

# %% [raw]
# five plots that can be plotted using the Pyplot module of Matplotlib:
# 1. Line Plot
# 2. Scatter Plot
# 3. Histogram Plot
# 4. Box Plot
# 5. Pie Chart

# %% [markdown]
# # Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data plot a scatter plot.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))

# %%
x
# Out:
# array([ 6.57725695,  3.8730197 ,  3.19299494, -0.72698541,  2.44522359,
#         2.29048204,  2.83451704,  1.74599865,  2.91236366,  2.04556394,
#         0.37227049,  4.76924476,  4.76263608,  6.41914613,  3.10006728,
#         2.19064517,  1.9092801 , -0.09295463,  4.96473487,  0.79786474,
#         0.62990695,  2.5887002 ,  5.97229671,  3.47343253,  0.95242972,
#         1.5740136 ,  4.25048993,  2.67897327,  1.4623273 ,  2.53993856,
#         4.49011253,  6.95222157,  0.51175334,  1.74716618,  1.39246781,
#        -1.83816635,  1.15241596,  0.95224848,  5.24795592,  2.73617153,
#        -0.24657089,  4.2933509 ,  2.28745848, -0.48628207,  1.80670072,
#         1.82281124,  1.2522354 ,  3.05942763, -1.49651554,  2.46447627])

# %%
y
# Out:
# array([ 5.02636688,  4.70559568,  5.216375  ,  5.23878131,  5.97508626,
#         0.76339863,  4.69166681, -0.72177906,  1.79422979, -0.82894409,
#         5.09629502,  5.66747564,  2.60517064,  6.54929006,  1.65054498,
#         3.30123373,  3.30589141,  0.87160945,  3.87589322,  6.87795692,
#         0.95013825,  4.79867689,  2.6909863 ,  6.53925461,  3.9675767 ,
#         4.3524328 ,  4.28632656,  3.49817341,  0.20847299,  5.78332582,
#         0.25866197,  3.47712638,  4.22815418,  1.32417545,  3.29012643,
#         5.33576457,  2.95179106,  1.22268516, -2.8314755 ,  1.05631899,
#         1.81784252,  1.96716526,  1.08000764,  3.75459047,  1.85058316,
#         2.78109133,  4.3581432 ,  1.28912566,  2.39958785,  7.31629868])

# %%
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.title("random data")
plt.scatter(x,y)
plt.show()

# %% [markdown]
# # Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.

# %%
plt.subplot(2,2,1)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([0, 100, 200, 300, 400, 500])
plt.scatter(x,y)


plt.subplot(2,2,2)
x = np.array([0, 1, 2, 3, 4, 5])  
y = np.array([50, 20, 40, 20, 60, 70])
plt.scatter(x,y)

plt.subplot(2,2,3)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([10, 20, 30, 40, 50, 60])
plt.scatter(x,y)

plt.subplot(2,2,4)
x = np.array([0, 1, 2, 3, 4, 5]) 
y = np.array([200, 350, 250, 550, 450, 150])
plt.scatter(x,y)

# %% [markdown]
# # Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.

# %% [raw]
# A bar plot (or bar chart) is a type of data visualization that represents categorical data with rectangular bars. The length or height of each bar is proportional to the value it represents. Bar plots are typically used to compare different categories of data.

# %%
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])

# %%
plt.bar(company,profit)
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
# box1 = np.random.normal(100, 10, 200)
# box2 = np.random.normal(90, 20, 200)

# %%
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)

# %%
box = [box1,box2]

# %%
plt.boxplot(box,  vert=True, patch_artist=True)
plt.show()
